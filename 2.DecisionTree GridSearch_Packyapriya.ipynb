# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age','bmi','children','sex_male','smoker_yes']]

# %%
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END criterion=squared_error, splitter=best;, score=0.759 total time=   0.0s
# [CV 2/5] END criterion=squared_error, splitter=best;, score=0.667 total time=   0.0s
# [CV 3/5] END criterion=squared_error, splitter=best;, score=0.732 total time=   0.0s
# [CV 4/5] END criterion=squared_error, splitter=best;, score=0.701 total time=   0.0s
# [CV 5/5] END criterion=squared_error, splitter=best;, score=0.681 total time=   0.0s
# [CV 1/5] END criterion=squared_error, splitter=random;, score=0.682 total time=   0.0s
# [CV 2/5] END criterion=squared_error, splitter=random;, score=0.604 total time=   0.0s
# [CV 3/5] END criterion=squared_error, splitter=random;, score=0.716 total time=   0.0s
# [CV 4/5] END criterion=squared_error, splitter=random;, score=0.756 total time=   0.0s
# [CV 5/5] END criterion=squared_error, splitter=random;, score=0.637 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, splitter=best;, score=0.740 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, splitter=best;, score=0.659 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, splitter=best;, score=0.760 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, splitter=best;, score=0.697 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, splitter=best;, score=0.686 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, splitter=random;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, splitter=random;, score=0.671 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, splitter=random;, score=0.696 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, splitter=random;, score=0.660 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, splitter=random;, score=0.748 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, splitter=best;, score=0.693 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, splitter=best;, score=0.688 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, splitter=best;, score=0.752 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, splitter=best;, score=0.703 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, splitter=best;, score=0.732 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, splitter=random;, score=0.704 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, splitter=random;, score=0.690 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, splitter=random;, score=0.705 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, splitter=random;, score=0.760 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, splitter=random;, score=0.745 total time=   0.0s
# [CV 1/5] END ..criterion=poisson, splitter=best;, score=0.755 total time=   0.0s
# [CV 2/5] END ..criterion=poisson, splitter=best;, score=0.655 total time=   0.0s
# [CV 3/5] END ..criterion=poisson, splitter=best;, score=0.676 total time=   0.0s
# [CV 4/5] END ..criterion=poisson, splitter=best;, score=0.687 total time=   0.0s
# [CV 5/5] END ..criterion=poisson, splitter=best;, score=0.711 total time=   0.0s
# [CV 1/5] END criterion=poisson, splitter=random;, score=0.645 total time=   0.0s
# [CV 2/5] END criterion=poisson, splitter=random;, score=0.634 total time=   0.0s
# [CV 3/5] END criterion=poisson, splitter=random;, score=0.667 total time=   0.0s
# [CV 4/5] END criterion=poisson, splitter=random;, score=0.722 total time=   0.0s
# [CV 5/5] END criterion=poisson, splitter=random;, score=0.707 total time=   0.0s
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter after tuning
result=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'criterion': 'absolute_error', 'splitter': 'random'}:

# %%
table=pd.DataFrame.from_dict(result)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.001707      0.003153         0.005782        0.002975
# 1       0.005321      0.004434         0.002678        0.002952
# 2       0.010196      0.003823         0.003524        0.002836
# 3       0.006031      0.005427         0.009210        0.006710
# 4       0.069069      0.016326         0.006680        0.005000
# 5       0.041477      0.011419         0.004573        0.005891
# 6       0.015496      0.001900         0.006301        0.005221
# 7       0.011905      0.006812         0.005489        0.007113
#
#   param_criterion param_splitter  \
# 0   squared_error           best
# 1   squared_error         random
# 2    friedman_mse           best
# 3    friedman_mse         random
# 4  absolute_error           best
# 5  absolute_error         random
# 6         poisson           best
# 7         poisson         random
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'splitter': 'be...           0.758882
# 1  {'criterion': 'squared_error', 'splitter': 'ra...           0.682176
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}           0.739950
# 3  {'criterion': 'friedman_mse', 'splitter': 'ran...           0.686271
# 4  {'criterion': 'absolute_error', 'splitter': 'b...           0.693273
# 5  {'criterion': 'absolute_error', 'splitter': 'r...           0.703878
# 6       {'criterion': 'poisson', 'splitter': 'best'}           0.755328
# 7     {'criterion': 'poisson', 'splitter': 'random'}           0.645207
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.666997           0.732418           0.700609           0.681143
# 1           0.603735           0.715709           0.756490           0.637038
# 2           0.659315           0.760164           0.697339           0.686318
# 3           0.671388           0.695592           0.660303           0.748340
# 4           0.687977           0.752349           0.703305           0.731613
# 5           0.689962           0.704731           0.760151           0.745249
# 6           0.655380           0.676089           0.687329           0.711489
# 7           0.633649           0.666670           0.722344           0.706655
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.708009        0.033593                4
# 1         0.679030        0.054384                7
# 2         0.708617        0.036589                3
# 3         0.692379        0.030492                6
# 4         0.713703        0.024502                2
# 5         0.720794        0.026988                1
# 6         0.697123        0.034278                5
# 7         0.674905        0.034381                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
chidren_input=float(input("Children:"))
sex_male_input=float(input("Sex Male 0 or 1:"))
smoker_yes_input=float(input("Smoker Yes 0 or 1"))
# Out:
# Age: 32
# BMI: 45
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,chidren_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction{}".format(Future_Prediction))
# Out:
# Future_Prediction[42112.]
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
